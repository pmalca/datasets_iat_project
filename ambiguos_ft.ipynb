# %%
import pandas as pd

# %%
file_paths = [
    r"D:\Proyectos\amag\classification\intermediate\appealed_orders_outcomes_2018.csv",
    r"D:\Proyectos\amag\classification\intermediate\appealed_orders_outcomes_2019.csv",
    r"D:\Proyectos\amag\classification\intermediate\appealed_orders_outcomes_2020.csv",
    r"D:\Proyectos\amag\classification\intermediate\appealed_orders_outcomes_2021.csv",
    r"D:\Proyectos\amag\classification\intermediate\appealed_orders_outcomes_2022.csv",
]

# Read and concatenate all CSV files into a single DataFrame
df = pd.concat([pd.read_csv(file) for file in file_paths], ignore_index=True)

# %%
df
# Out:
#                         case_file                                        id  \
# 0      00011-2018-0-0212-JP-CI-01  documentoD.html?nid=xDJSaOEoEZmlFmwEOPUr
# 1      00020-2018-0-0201-JP-CI-02   documentoD.html?nid=pJdyJvOzEIJstCoVjPV
# 2      00010-2018-0-0201-JP-FC-01       documentoD.html?nid=fhuaIhZLApVjWHt
# 3     00015-2018-25-0201-JP-FC-02   documentoD.html?nid=yqntOXZZMMxHspewOkd
# 4     00062-2018-49-0210-JP-FC-01   documentoD.html?nid=oIzKKXgjxsjoCDlHQMn
# ...                           ...                                       ...
# 8107   00024-2022-0-3398-JR-CI-01      documentoD.html?nid=QPCcKbseqNUPzvWa
# 8108   00005-2022-0-3301-JR-CI-01       documentoD.html?nid=ZRnFdXBfQymaMUI
# 8109   00012-2022-2-3301-JR-FT-01       documentoD.html?nid=HtqovpuRYZtXUih
# 8110   00018-2022-1-3398-JR-FT-02      documentoD.html?nid=vqTpYBDiahzMbWNV
# 8111   00004-2022-0-3301-SP-FC-01     documentoD.html?nid=DrgspBxZkIyQmEZDG
#
# ...

# %%
df['outcome'].value_counts()
# Out:
# Confirmation    4955
# Reversal        2447
# Ambiguous        710
# Name: outcome, dtype: int64

# %%
ambiguous_ids = df.loc[df['outcome'] == 'Ambiguous', 'case_file']

# Separate IDs for the other five categories
other_categories_ids = df.loc[df['outcome'] != 'Ambiguous', 'case_file']

# Find 'Ambiguous' IDs that are not in the other categories
unique_ambiguous_ids = ambiguous_ids[~ambiguous_ids.isin(other_categories_ids)]

# Filter the DataFrame to display the rows with unique 'Ambiguous' IDs
orders_a = df[(df['outcome'] == 'Ambiguous') & (df['case_file'].isin(unique_ambiguous_ids))]

orders_a
# Out:
#                         case_file                                        id  \
# 7     00114-2018-62-0201-JP-FC-01   documentoD.html?nid=zTKszXMMHuFAdMMPrqE
# 37     00738-2018-0-0201-JP-FC-02      documentoD.html?nid=BFqudTDkjPzSXREM
# 63     00036-2018-0-0301-JP-CI-01       documentoD.html?nid=bdVZMBmblzryabS
# 66     00128-2018-0-0301-JP-LA-04      documentoD.html?nid=bpIweapNtmOaxNBT
# 70     00045-2018-0-0401-JP-CI-02     documentoD.html?nid=eRHIVWgtIjGAfvPdP
# ...                           ...                                       ...
# 8065   00024-2022-0-2402-JP-CI-01      documentoD.html?nid=UbhDeqydEZKkEHkY
# 8068   00037-2022-0-2402-JP-CI-01  documentoD.html?nid=BJzZBVLcMwEBhGLYoZqv
# 8069  00051-2022-15-2402-JP-CI-01  documentoD.html?nid=CajRJQMRLHzmhfJOKsiT
# 8082   00217-2022-0-2402-JP-CI-01  documentoD.html?nid=jWdbAQbWZpjuVQlVyDQi
# 8087  00051-2022-15-2402-JP-CI-01      documentoD.html?nid=yNfPddUFLZxdUklK
#
# ...

# %%
orders_a['law_field'].value_counts()
# Out:
# CIVIL                     296
# LABORAL                   175
# FAMILIA CIVIL             152
# DERECHO CONSTITUCIONAL     29
# FAMILIA TUTELAR            17
# COMERCIAL                  13
# CONTENCIOSO ADM.            2
# Name: law_field, dtype: int64

# %%
orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))
sampled_df = orders_a.groupby('law_field').apply(lambda x: x.sample(n=min(len(x), 15), random_state=42).reset_index(drop=True))
sampled_df = sampled_df.drop(columns=['opinion_text'])
sampled_df.to_excel(r'D:\Proyectos\amag\classification\aoo_finetuning.xlsx', index=False)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_27780\480802886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[24], line 4
#       2 sampled_df = orders_a.groupby('law_field').apply(lambda x: x.sample(n=min(len(x), 15), random_state=42).reset_index(drop=True))
#       3 sampled_df = sampled_df.drop(columns=['opinion_text'])
# ----> 4 sampled_df.to_excel(r'D:\Proyectos\amag\classification\aoo_finetuning.xlsx', index=False)
#
# ...

# %% [markdown]
# ## Orders Outcomes

# %%
import pandas as pd

# %%
file_paths = [
    r"D:\Proyectos\amag\classification\intermediate\orders_outcomes_2018.csv",
    r"D:\Proyectos\amag\classification\intermediate\orders_outcomes_2019.csv",
    r"D:\Proyectos\amag\classification\intermediate\orders_outcomes_2020.csv",
    r"D:\Proyectos\amag\classification\intermediate\orders_outcomes_2021.csv",
    r"D:\Proyectos\amag\classification\intermediate\orders_outcomes_2022.csv",
]

# Read and concatenate all CSV files into a single DataFrame
df = pd.concat([pd.read_csv(file) for file in file_paths], ignore_index=True)

# %%
orders_a = df[df['outcome'].str.contains('Ambiguous', case=False, na=False)]
orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))
orders_a.to_csv(r'D:\Proyectos\amag\classification\amb_orders_77k.csv', index=False)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14900\1766483074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))

# %%
orders_a.to_csv(r'D:\Proyectos\amag\classification\amb_orders.csv', index=False)

# %%
ambiguous_ids = df.loc[df['outcome'] == 'Ambiguous', 'case_file']

# Separate IDs for the other five categories
other_categories_ids = df.loc[df['outcome'] != 'Ambiguous', 'case_file']

# Find 'Ambiguous' IDs that are not in the other categories
unique_ambiguous_ids = ambiguous_ids[~ambiguous_ids.isin(other_categories_ids)]

# Filter the DataFrame to display the rows with unique 'Ambiguous' IDs
orders_a = df[(df['outcome'] == 'Ambiguous') & (df['case_file'].isin(unique_ambiguous_ids))]

orders_a
# Out:
#                          case_file                                       id  \
# 22      00006-2018-0-0201-JP-FC-01     documentoD.html?nid=TSZgNzieKzbRTYMp
# 34      00041-2018-0-0201-JP-FC-02      documentoD.html?nid=JjpykikLtvZJxNj
# 35      00042-2018-0-0204-JP-FC-01     documentoD.html?nid=BDvDduLDpfeWfvYk
# 36      00046-2018-0-0201-JP-FC-01   documentoD.html?nid=ZizPSmoxVfZOiSnAnW
# 40      00057-2018-0-0201-JP-FC-02   documentoD.html?nid=kjEGnVDTAnrypPrYqr
# ...                            ...                                      ...
# 201426  00107-2022-0-2402-JP-CI-01  documentoD.html?nid=FZCyZoMFmCUQeSheNbc
# 201427  00111-2022-0-2402-JP-CI-01      documentoD.html?nid=vvOCAYUOBIZJmJA
# 201428  00111-2022-0-2402-JP-CI-01      documentoD.html?nid=oflAlfLqLtZPLSP
# 201429  00111-2022-0-2402-JP-CI-01    documentoD.html?nid=KPUfuJOyalfUXbHxt
# 201435  00179-2022-4-2402-JR-CI-01    documentoD.html?nid=pkWwzwzcdFoCozGWb
#
# ...

# %%
orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_4216\168388180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))

# %%
orders_a['law_field'].value_counts()
# Out:
# FAMILIA CIVIL             34650
# FAMILIA TUTELAR           24211
# CIVIL                      4522
# LABORAL                    2564
# CONTENCIOSO ADM.            143
# COMERCIAL                   110
# DERECHO CONSTITUCIONAL        8
# Name: law_field, dtype: int64

# %%
orders_a.to_csv(r'D:\Proyectos\amag\classification\amb_orders.csv', index=False)

# %%
sampled_df = orders_a.groupby('law_field').apply(lambda x: x.sample(n=min(len(x), 20)).reset_index(drop=True))
sampled_df = sampled_df.drop(columns=['opinion_text'])
sampled_df.to_excel(r'D:\Proyectos\amag\classification\oo_finetuning.xlsx', index=False)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17220\726904389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_a['input'] = (orders_a['summary'].fillna('') + ' ' + orders_a['resolution_type'].fillna('')+ ' ' + orders_a['verdict_text'].fillna(''))

# %% [markdown]
# ## Finetuning the model

# %%
oo_ft = pd.read_excel(r"D:\Proyectos\amag\classification\oo_finetuning_VF.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 oo_ft = pd.read_excel(r"D:\Proyectos\amag\classification\oo_finetuning_VF.xlsx")
#
# File d:\Programas\anaconda3\envs\datasets_iat\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File d:\Programas\anaconda3\envs\datasets_iat\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
oo_ft['outcome_ALEXIS'].value_counts()
# Out:
# 6. Irrelevante                     78
# 1. Demandante                      66
# 2. Demandado                       27
# 4. Abandonado por el Demandante    11
# Name: outcome_ALEXIS, dtype: int64

# %%
def convert_to_custom_format(dataset):
    converted_data = []
    for _, row in dataset.iterrows():
        json_dict = {
            "messages": [
                {"role": "system", "content": "Clasifica el siguiente fragmento de una decisión judicial en sólo una de las siguientes seis categorías: '1. Demandante', cuando la decisión es favorable al demandante, porque se declara fundada la pretensión, o se dictan medidas de protección a su favor; '2. Demandado', cuando la decisión es favorable al demandado, ya sea porque se desestima la pretensión del demandante, se declara infundada la pretensión, existe una nulidad, se declara la improcedencia o no se dictan medidas de protección; '4. Abandonado por el Demandante', cuando el caso ha concluido porque el demandante no ha asistido al proceso o ha mostrado desinterés en su resultado; '6. Irrelevante' cuando no es posible precisar el sentido del fallo. Sólo escribe el nombre de la categoría. Fragmento de la decisión judicial:"},
                {"role": "user", "content": row['input']},
                {"role": "assistant", "content": row['outcome_ALEXIS']}
            ]
        }
        converted_data.append(json_dict)
    return converted_data

converted_data = convert_to_custom_format(oo_ft)

# %%
from sklearn.model_selection import train_test_split

# Stratified splitting. Assuming 'Top Category' can be used for stratification
train_data, val_data = train_test_split(
    converted_data,
    test_size=0.2,
    stratify=oo_ft['outcome_ALEXIS'],
    random_state=42  # for reproducibility
)

# %%
import json  
def write_to_jsonl(data, file_path):
    with open(file_path, 'w') as file:
        for entry in data:
            json.dump(entry, file)
            file.write('\n')

training_file_name = "train_oo.jsonl"
validation_file_name = "val_oo.jsonl"

write_to_jsonl(train_data, training_file_name)
write_to_jsonl(val_data, validation_file_name)

# %% [markdown]
# ## Testing the model

# %%
orders_a
# Out:
#                          case_file                                       id  \
# 22      00006-2018-0-0201-JP-FC-01     documentoD.html?nid=TSZgNzieKzbRTYMp
# 34      00041-2018-0-0201-JP-FC-02      documentoD.html?nid=JjpykikLtvZJxNj
# 35      00042-2018-0-0204-JP-FC-01     documentoD.html?nid=BDvDduLDpfeWfvYk
# 36      00046-2018-0-0201-JP-FC-01   documentoD.html?nid=ZizPSmoxVfZOiSnAnW
# 40      00057-2018-0-0201-JP-FC-02   documentoD.html?nid=kjEGnVDTAnrypPrYqr
# ...                            ...                                      ...
# 201426  00107-2022-0-2402-JP-CI-01  documentoD.html?nid=FZCyZoMFmCUQeSheNbc
# 201427  00111-2022-0-2402-JP-CI-01      documentoD.html?nid=vvOCAYUOBIZJmJA
# 201428  00111-2022-0-2402-JP-CI-01      documentoD.html?nid=oflAlfLqLtZPLSP
# 201429  00111-2022-0-2402-JP-CI-01    documentoD.html?nid=KPUfuJOyalfUXbHxt
# 201435  00179-2022-4-2402-JR-CI-01    documentoD.html?nid=pkWwzwzcdFoCozGWb
#
# ...

# %%
oo_ft = pd.read_excel(r"D:\Proyectos\amag\fine_tuning\oo_finetuning_VF.xlsx")
oo_ft
# Out:
#                       case_file                                        id  \
# 0    00038-2019-0-1201-JR-CI-02      documentoD.html?nid=gdOzVxixLsfGRrqv
# 1    00026-2022-0-0301-JP-CI-04      documentoD.html?nid=RGhfTIQWppMkEZvk
# 2    00034-2018-0-2503-JM-CI-01  documentoD.html?nid=ukEeUOQldLXPWjqEBPLp
# 3    00175-2018-0-1301-JP-CI-01       documentoD.html?nid=jbtekitOtIvKKuP
# 4    00206-2019-0-1401-JR-CI-03      documentoD.html?nid=MHEPRvcjOPhhOQHQ
# ..                          ...                                       ...
# 177  00511-2019-0-1411-JP-FC-01     documentoD.html?nid=iqrQoqeXCvhiQBweL
# 178  00041-2021-0-0805-JP-FC-01     documentoD.html?nid=twJjQnUEoqmBnroMm
# 179  00180-2018-0-1201-JP-FC-01    documentoD.html?nid=eEeYcAnbqJiXfNNwBj
# 180  00229-2022-0-0513-JM-FT-01    documentoD.html?nid=HFmlChmuClzrNRYJYr
# 181  00078-2022-0-2402-JP-CI-01  documentoD.html?nid=RXWQTLBniwzSTskTmCbY
#
#     issued_date resolution_number             resolution_type notified_date  \
# ...

# %%
oo_ft_ids = oo_ft['id']

# Filter 'orders_a' to keep only the rows where 'id' is not in 'oo_ft_ids'
unique_rows = orders_a[~orders_a['id'].isin(oo_ft_ids)]

# %%
unique_rows
# Out:
#                          case_file                                       id  \
# 22      00006-2018-0-0201-JP-FC-01     documentoD.html?nid=TSZgNzieKzbRTYMp
# 34      00041-2018-0-0201-JP-FC-02      documentoD.html?nid=JjpykikLtvZJxNj
# 35      00042-2018-0-0204-JP-FC-01     documentoD.html?nid=BDvDduLDpfeWfvYk
# 36      00046-2018-0-0201-JP-FC-01   documentoD.html?nid=ZizPSmoxVfZOiSnAnW
# 40      00057-2018-0-0201-JP-FC-02   documentoD.html?nid=kjEGnVDTAnrypPrYqr
# ...                            ...                                      ...
# 201426  00107-2022-0-2402-JP-CI-01  documentoD.html?nid=FZCyZoMFmCUQeSheNbc
# 201427  00111-2022-0-2402-JP-CI-01      documentoD.html?nid=vvOCAYUOBIZJmJA
# 201428  00111-2022-0-2402-JP-CI-01      documentoD.html?nid=oflAlfLqLtZPLSP
# 201429  00111-2022-0-2402-JP-CI-01    documentoD.html?nid=KPUfuJOyalfUXbHxt
# 201435  00179-2022-4-2402-JR-CI-01    documentoD.html?nid=pkWwzwzcdFoCozGWb
#
# ...

# %%
sampled_df = unique_rows.groupby('law_field').apply(lambda x: x.sample(n=min(len(x), 20)).reset_index(drop=True))
sampled_df
# Out:
#                                case_file  \
# law_field
# CIVIL     0   00011-2022-0-0601-JR-CI-03
#           1   00065-2018-0-2502-JM-CI-01
#           2   00023-2018-0-1101-SP-CI-01
#           3   00203-2022-0-1509-JR-CI-01
#           4   00167-2018-0-2801-JM-CI-02
# ...                                  ...
# LABORAL   15  00016-2019-0-0805-JP-LA-01
#           16  00008-2019-0-2402-JP-LA-02
#           17  01422-2020-0-1801-JP-LA-06
#           18  00525-2018-0-2801-JP-LA-01
#           19  00086-2018-0-1801-SP-LA-47
#
#                                                     id issued_date  \
# law_field
# CIVIL     0    documentoD.html?nid=iCeBGnXyEZATyfQxqDR  2022-02-22
#           1     documentoD.html?nid=GzbKJXxZytSlkuzMll  2019-12-16
#           2    documentoD.html?nid=scgAhYMXOthysxDvAUJ  2018-11-06
#           3   documentoD.html?nid=eiluuCypGwtBYTYQCEBy  2022-05-12
#           4       documentoD.html?nid=HeMLwlXHnMpIydUI  2018-02-07
# ...

# %%
import openai
from openai import OpenAI

# %%
client = OpenAI()

def generate_output(text):
    try:
        # Create chat completion
        completion = client.chat.completions.create(
            model="ft:gpt-4o-mini-2024-07-18:personal:amag-orders-amb:A2mTHLtS",
            messages=[
                {"role": "system", "content": "Clasifica el siguiente fragmento de una decisión judicial en sólo una de las siguientes seis categorías: '1. Demandante', cuando la decisión es favorable al demandante, porque se declara fundada la pretensión, o se dictan medidas de protección a su favor; '2. Demandado', cuando la decisión es favorable al demandado, ya sea porque se desestima la pretensión del demandante, se declara infundada la pretensión, existe una nulidad, se declara la improcedencia o no se dictan medidas de protección; '4. Abandonado por el Demandante', cuando el caso ha concluido porque el demandante no ha asistido al proceso o ha mostrado desinterés en su resultado; '6. Irrelevante' cuando no es posible precisar el sentido del fallo. Sólo escribe el nombre de la categoría. Fragmento de la decisión judicial:"},
                {"role": "user", "content": text}
            ]
        )
        return completion.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")

sampled_df['outcome_GPT'] = sampled_df['input'].apply(generate_output)

# %%
sampled_df
# Out:
#                                case_file  \
# law_field
# CIVIL     0   00011-2022-0-0601-JR-CI-03
#           1   00065-2018-0-2502-JM-CI-01
#           2   00023-2018-0-1101-SP-CI-01
#           3   00203-2022-0-1509-JR-CI-01
#           4   00167-2018-0-2801-JM-CI-02
# ...                                  ...
# LABORAL   15  00016-2019-0-0805-JP-LA-01
#           16  00008-2019-0-2402-JP-LA-02
#           17  01422-2020-0-1801-JP-LA-06
#           18  00525-2018-0-2801-JP-LA-01
#           19  00086-2018-0-1801-SP-LA-47
#
#                                                     id issued_date  \
# law_field
# CIVIL     0    documentoD.html?nid=iCeBGnXyEZATyfQxqDR  2022-02-22
#           1     documentoD.html?nid=GzbKJXxZytSlkuzMll  2019-12-16
#           2    documentoD.html?nid=scgAhYMXOthysxDvAUJ  2018-11-06
#           3   documentoD.html?nid=eiluuCypGwtBYTYQCEBy  2022-05-12
#           4       documentoD.html?nid=HeMLwlXHnMpIydUI  2018-02-07
# ...

# %%
sampled_df = sampled_df.drop(columns=['opinion_text'])

sampled_df.to_excel(r'D:\Proyectos\amag\fine_tuning\orders_outcomes_GPT.xlsx', index=False)

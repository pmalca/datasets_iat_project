# %%
import pandas as pd

# %% [markdown]
# ## Step 1: Creating the IAT judges list

# %% [markdown]
# ### Creating the judge list with its IAT score for AMAG I

# %%
iat_i = pd.read_csv(r"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\01_AMAG\03_Intermediate\iat_data_clean.csv")

iat_i = iat_i.dropna(subset=['iat_score'])

# Optionally, you can reset the index after dropping rows
iat_i = iat_i.reset_index(drop=True)

# %%
df_i = pd.read_csv(r"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\01_AMAG\03_Intermediate\PCA_2020_all_participants.csv")

# %%
amag_i = pd.merge(iat_i, df_i, left_on='nrodocumento', right_on='dni', how='inner')

# Count the number of identical values
num_identical = len(amag_i)

print(f"Number of identical values between 'DNI' and 'nrodocumento': {num_identical}")
# Out:
# Number of identical values between 'DNI' and 'nrodocumento': 313

# %%
amag_i["participant_apellido_nombre"] = amag_i["apellido_paterno"] + " " + amag_i["apellido_materno"] + " " + amag_i["nombres"]
amag_i["participant_apellido_nombre"] = amag_i["participant_apellido_nombre"].str.strip()

amag_i["participant_nombre_apellido"] = amag_i["nombres"] + " " + amag_i["apellido_paterno"] + " " + amag_i["apellido_materno"]
amag_i["participant_nombre_apellido"] = amag_i["participant_nombre_apellido"].str.strip()

# %%
# Select specific columns: ApellidoPaterno, ApellidoMaterno, Nombres
amag_i = amag_i[['participant_apellido_nombre', 'participant_nombre_apellido', 'nombres' ,'iat_score']]

# %%
amag_i.rename(columns={'nombres': 'names'}, inplace=True)

# Take into account I'm not filtering by charge, since in this dataset we only have information about affiliated institution, and not the charge

# %% [markdown]
# ### Creating the judge list with its IAT score for AMAG II

# %%
amag_ii = pd.read_stata(r"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\08_CEJ_Web\data_cleaned\lab_data\Clean_Full_Data12.dta")

# %%
# Filter rows where the 'Cargo' column contains 'JUEZ', remember for amag i I cannot do this filter. 
amag_ii = amag_ii[amag_ii['Cargo'].str.contains('JUEZ', na=False)]

# Select specific columns: ApellidoPaterno, ApellidoMaterno, Nombres
amag_ii = amag_ii[['ApellidoPaterno', 'ApellidoMaterno', 'Nombres' ,'bs_iat_score']]

amag_ii = amag_ii.dropna(subset=['bs_iat_score'])

# %%
amag_ii["participant_apellido_nombre"] = amag_ii["ApellidoPaterno"] + " " + amag_ii["ApellidoMaterno"] + " " + amag_ii["Nombres"]
amag_ii["participant_apellido_nombre"] = amag_ii["participant_apellido_nombre"].str.strip()

amag_ii["participant_nombre_apellido"] = amag_ii["Nombres"] + " " +  amag_ii["ApellidoPaterno"] + " " + amag_ii["ApellidoMaterno"]
amag_ii["participant_nombre_apellido"] = amag_ii["participant_nombre_apellido"].str.strip()

# %%
amag_ii.rename(columns={'Nombres': 'names', 'bs_iat_score': 'iat_score'}, inplace=True)
amag_ii = amag_ii[['participant_apellido_nombre', 'participant_nombre_apellido', 'names' ,'iat_score']]
# Out:
#               participant_apellido_nombre  \
# 44             SALAZAR DIAZ VLADIMIR OMAR
# 53             SUPANTA CONDOR MARINA INES
# 59             LINARES REBAZA DYRAN JORGE
# 84          CLEMENTE SALOME DILMA ZORAIDA
# 88            VIVIANO VALDEZ ROMAIN IGORT
# ...                                   ...
# 5476         ASMAD CORCUERA MARCO ANTONIO
# 5528              MIO LOPEZ FLOR GRACIELA
# 5571           AGUILAR BAZAN MARLY YOHANA
# 5724         SANTILLAN TUESTA JUAN CARLOS
# 5845  BASAGOITIA CARDENAS JONATAN ORLANDO
#
#               participant_nombre_apellido            names  iat_score
# 44             VLADIMIR OMAR SALAZAR DIAZ    VLADIMIR OMAR   0.087537
# 53             MARINA INES SUPANTA CONDOR      MARINA INES  -0.663009
# 59             DYRAN JORGE LINARES REBAZA      DYRAN JORGE  -0.236486
# 84          DILMA ZORAIDA CLEMENTE SALOME    DILMA ZORAIDA  -0.250922
# 88            ROMAIN IGORT VIVIANO VALDEZ     ROMAIN IGORT  -0.483749
# ...                                   ...              ...        ...
# 5476         MARCO ANTONIO ASMAD CORCUERA    MARCO ANTONIO  -0.265571
# 5528              FLOR GRACIELA MIO LOPEZ    FLOR GRACIELA  -0.160823
# 5571           MARLY YOHANA AGUILAR BAZAN     MARLY YOHANA  -0.243329
# 5724         JUAN CARLOS SANTILLAN TUESTA      JUAN CARLOS   0.088814
# 5845  JONATAN ORLANDO BASAGOITIA CARDENAS  JONATAN ORLANDO   0.291353
#
# [90 rows x 4 columns]

# %% [markdown]
# ### Consolidating in one list amag I and amag II

# %%
amag_i.head()
# Out:
#           participant_apellido_nombre         participant_nombre_apellido  \
# 0  PEREZ CALDERON PATRICIA DEL CARMEN  PATRICIA DEL CARMEN PEREZ CALDERON
# 1           FRISANCHO ENRIQUEZ CARLOS           CARLOS FRISANCHO ENRIQUEZ
# 2      VALDIVIA CALDERON LUIS ENRIQUE      LUIS ENRIQUE VALDIVIA CALDERON
# 3       VITERI VALIENTE YESSICA PAOLA       YESSICA PAOLA VITERI VALIENTE
# 4        TICONA MIRANDA MARCO ANTONIO        MARCO ANTONIO TICONA MIRANDA
#
#                  names  iat_score
# 0  PATRICIA DEL CARMEN  -0.176195
# 1               CARLOS  -0.646047
# 2         LUIS ENRIQUE  -0.708610
# 3        YESSICA PAOLA  -0.255366
# 4        MARCO ANTONIO  -0.019535

# %%
amag_ii.head()
# Out:
#       participant_apellido_nombre    participant_nombre_apellido  \
# 44     SALAZAR DIAZ VLADIMIR OMAR     VLADIMIR OMAR SALAZAR DIAZ
# 53     SUPANTA CONDOR MARINA INES     MARINA INES SUPANTA CONDOR
# 59     LINARES REBAZA DYRAN JORGE     DYRAN JORGE LINARES REBAZA
# 84  CLEMENTE SALOME DILMA ZORAIDA  DILMA ZORAIDA CLEMENTE SALOME
# 88    VIVIANO VALDEZ ROMAIN IGORT    ROMAIN IGORT VIVIANO VALDEZ
#
#             names  iat_score
# 44  VLADIMIR OMAR   0.087537
# 53    MARINA INES  -0.663009
# 59    DYRAN JORGE  -0.236486
# 84  DILMA ZORAIDA  -0.250922
# 88   ROMAIN IGORT  -0.483749

# %%
amag = pd.concat([amag_i, amag_ii], ignore_index=True)
amag
# Out:
#              participant_apellido_nombre          participant_nombre_apellido  \
# 0     PEREZ CALDERON PATRICIA DEL CARMEN   PATRICIA DEL CARMEN PEREZ CALDERON
# 1              FRISANCHO ENRIQUEZ CARLOS            CARLOS FRISANCHO ENRIQUEZ
# 2         VALDIVIA CALDERON LUIS ENRIQUE       LUIS ENRIQUE VALDIVIA CALDERON
# 3          VITERI VALIENTE YESSICA PAOLA        YESSICA PAOLA VITERI VALIENTE
# 4           TICONA MIRANDA MARCO ANTONIO         MARCO ANTONIO TICONA MIRANDA
# ..                                   ...                                  ...
# 398         ASMAD CORCUERA MARCO ANTONIO         MARCO ANTONIO ASMAD CORCUERA
# 399              MIO LOPEZ FLOR GRACIELA              FLOR GRACIELA MIO LOPEZ
# 400           AGUILAR BAZAN MARLY YOHANA           MARLY YOHANA AGUILAR BAZAN
# 401         SANTILLAN TUESTA JUAN CARLOS         JUAN CARLOS SANTILLAN TUESTA
# 402  BASAGOITIA CARDENAS JONATAN ORLANDO  JONATAN ORLANDO BASAGOITIA CARDENAS
#
#                    names  iat_score
# 0    PATRICIA DEL CARMEN  -0.176195
# 1                 CARLOS  -0.646047
# 2           LUIS ENRIQUE  -0.708610
# 3          YESSICA PAOLA  -0.255366
# 4          MARCO ANTONIO  -0.019535
# ..                   ...        ...
# 398        MARCO ANTONIO  -0.265571
# 399        FLOR GRACIELA  -0.160823
# 400         MARLY YOHANA  -0.243329
# 401          JUAN CARLOS   0.088814
# 402      JONATAN ORLANDO   0.291353
#
# [403 rows x 4 columns]

# %%
amag.to_csv(r"D:\Proyectos\amag\iat_bernardo\iat_list.csv", index= False)

# %% [markdown]
# ## Step 2: Creating the judges outcomes

# %% [markdown]
# ### Reading our final decisions
#
# Since this a test code, we will only work with the case files with final decisions and  no second instance decisions, from 2018.
#
# However, this code could be modify it to work with the other case files.

# %%
judgements = pd.read_csv(r"D:\Proyectos\amag\classification\intermediate\judgements_case_file_2018.csv")
orders = pd.read_csv(r"D:\Proyectos\amag\classification\intermediate\orders_case_file_2018.csv")
final_decisions = pd.concat([judgements, orders], ignore_index=True)

# %%
final_decisions.drop(columns=['score'], inplace=True)

# %%
first_instance = final_decisions[final_decisions['second_instance'] == False]
first_instance
# Out:
#                          case_file                                        id  \
# 0       00006-2018-0-0210-JP-FC-01       documentoD.html?nid=GoktBpGEdOROVEm
# 1       00006-2018-0-0215-JP-FC-01   documentoD.html?nid=JduMwGNHzBYHcRxVouD
# 2       00007-2018-0-0201-JP-FC-02     documentoD.html?nid=yyHFwZbLpJQIWNYQJ
# 3       00008-2018-0-0201-JP-FC-01     documentoD.html?nid=IEsgCKwvAcFQGWpZh
# 4       00022-2018-0-0201-JP-FC-01  documentoD.html?nid=ajijiYXWiaSBOMMNrYdB
# ...                            ...                                       ...
# 101685  00670-2018-0-3301-JR-FT-01     documentoD.html?nid=ecUbLzbNBWucOMqMk
# 101686  00671-2018-0-3301-JR-FT-01     documentoD.html?nid=yAeyZStouvtVKisRi
# 101687  00672-2018-0-3301-JR-FT-01   documentoD.html?nid=tVdaUiHInwcDcIVKBkJ
# 101688  00673-2018-0-3301-JR-FT-01     documentoD.html?nid=aomgGMFOLByXAeHNc
# 101689  00675-2018-0-3301-JR-FT-01    documentoD.html?nid=IYVFnMmMIDriWrjPIn
#
#        issued_date resolution_number resolution_type notified_date  \
# 0       2021-02-08             TRECE       SENTENCIA    24/08/2021
# 1       2021-12-08        VEINTIOCHO       SENTENCIA    25/08/2021
# 2       2020-10-30        DIECISIETE       SENTENCIA    30/10/2020
# 3       2019-10-29              ONCE       SENTENCIA    29/10/2019
# 4       2019-12-04              DOCE       SENTENCIA    13/04/2019
# ...            ...               ...             ...           ...
# 101685  2018-08-08               UNO      AUTO FINAL    08/08/2018
# 101686  2018-09-08               UNO      AUTO FINAL    09/08/2018
# 101687  2018-04-23               UNO      AUTO FINAL    23/04/2018
# 101688  2018-09-08               UNO      AUTO FINAL    09/08/2018
# 101689  2018-08-17               UNO      AUTO FINAL    17/08/2018
#
#                                                   summary  \
# 0       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDECISIÓN:\nP...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFALLA: DECLA...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFALLA:\n\n1....
# 3       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSENTENCIAS\n...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t1.\tDECLARAR...
# ...                                                   ...
# 101685  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t, SE RESUELV...
# 101686  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSE RESUELVE:...
# 101687  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEL CESE INME...
# 101688  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSE RESUELVE:...
# 101689  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSE RESUELVE:...
#
#                                                   court  \
# 0               JUZGADO DE PAZ LETRADO - Sede Pomabamba
# 1       JUZGADO DE PAZ LETRADO ITINERANTE-Sede Asunción
# 2                     2° JUZGADO FAMILIA - Sede Central
# 3               3°JUZGADO DE PAZ LETRADO - Sede Central
# 4                 1° JUZGADO PAZ LETRADO - Sede Central
# ...                                                 ...
# 101685                       JUZGADO CIVIL - SEDE ANCON
# 101686                       JUZGADO CIVIL - SEDE ANCON
# 101687    1° JUZGADO DE FAMILIA DE VENTANILLA Y MI PERÚ
# 101688                       JUZGADO CIVIL - SEDE ANCON
# 101689         JUZGADO DE FAMILIA DE ANCÓN Y SANTA ROSA
#
#                  judicial_district                             judge  \
# 0                           ANCASH         ALVAREZ ACERO ROCIO DELSY
# 1                           ANCASH     HINOSTROZA HUERTA HILDA MARIA
# 2                           ANCASH         VILLAFAN CANO HOMMER FREY
# 3                           ANCASH  HUERTA BOJORQUEZ, CARMEN EUGENIA
# 4                           ANCASH      RETUERTO TUEROS BESSI YOHANA
# ...                            ...                               ...
# 101685  PUENTE PIEDRA - VENTANILLA                     <NO DEFINIDO>
# 101686  PUENTE PIEDRA - VENTANILLA                     <NO DEFINIDO>
# 101687  PUENTE PIEDRA - VENTANILLA        KATHERINE LA ROSA CASTILLO
# 101688  PUENTE PIEDRA - VENTANILLA                     <NO DEFINIDO>
# 101689  PUENTE PIEDRA - VENTANILLA     VITERI VALIENTE YESSICA PAOLA
#
#         start_date procedure_type        law_field  \
# 0       2018-01-11       ESPECIAL    FAMILIA CIVIL
# 1       2018-04-12          UNICO    FAMILIA CIVIL
# 2       2018-01-05          UNICO    FAMILIA CIVIL
# 3       2018-01-05          UNICO    FAMILIA CIVIL
# 4       2018-01-10          UNICO    FAMILIA CIVIL
# ...            ...            ...              ...
# 101685  2018-08-06          UNICO  FAMILIA TUTELAR
# 101686  2018-08-06          UNICO  FAMILIA TUTELAR
# 101687  2018-04-20          UNICO  FAMILIA TUTELAR
# 101688  2018-08-06          UNICO  FAMILIA TUTELAR
# 101689  2018-08-07          UNICO  FAMILIA TUTELAR
#
#                                             sub_law_field  \
# 0       DECLARACION JUDICIAL DE PATERNIDAD EXTRAMATRIM...
# 1                                    AUMENTO DE ALIMENTOS
# 2                                EXONERACION DE ALIMENTOS
# 3                                               ALIMENTOS
# 4                                               ALIMENTOS
# ...                                                   ...
# 101685                                 VIOLENCIA FAMILIAR
# 101686                                 VIOLENCIA FAMILIAR
# 101687                                 VIOLENCIA FAMILIAR
# 101688                                 VIOLENCIA FAMILIAR
# 101689                                 VIOLENCIA FAMILIAR
#
#                                              opinion_text  \
# 0       JUZGADO DE PAZ LETRADO - Sede Pomabamba \nEXPE...
# 1       JUZGADO DE PAZ LETRADO ITINERANTE-Sede Asunció...
# 2       CORTE SUPERIOR DE JUSTICIA DE ANCASH \n\nTERCE...
# 3                                                CORTE...
# 4        \n1° JUZGADO PAZ LETRADO - Sede Central- Loca...
# ...                                                   ...
# 101685  \n                  CORTE SUPERIOR DE JUSTICIA...
# 101686  \n                  CORTE SUPERIOR DE JUSTICIA...
# 101687  \n\n1° JUZGADO DE FAMILIA - SEDE ANEXO 1\nEXPE...
# 101688  \n                  CORTE SUPERIOR DE JUSTICIA...
# 101689  \n                  CORTE SUPERIOR DE JUSTICIA...
#
#                       judge_from_opinion  second_instance  days_difference
# 0              ALVAREZ ACERO ROCIO DELSY            False           1124.0
# 1          HINOSTROZA HUERTA HILDA MARIA            False           1336.0
# 2              VILLAFAN CANO HOMMER FREY            False           1029.0
# 3       HUERTA BOJORQUEZ, CARMEN EUGENIA            False            662.0
# 4           RETUERTO TUEROS BESSI YOHANA            False            693.0
# ...                                  ...              ...              ...
# 101685          ROY ESTEBAN ALVA NAVARRO            False              2.0
# 101686          ROY ESTEBAN ALVA NAVARRO            False             33.0
# 101687        KATHERINE LA ROSA CASTILLO            False              3.0
# 101688          ROY ESTEBAN ALVA NAVARRO            False             33.0
# 101689          ROY ESTEBAN ALVA NAVARRO            False             10.0
#
# [83872 rows x 18 columns]

# %%
cell_value = first_instance.iat[83870, 6]
cell_value
# Out:
# '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSE RESUELVE: DICTAR MEDIDA DE PROTECCIÓN A FAVOR DE LA PARTE AGRAVIADA\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# The keyword approach is not the best, since it has so much limitations. 
# Remember we are working with case files from different law fields, so the judge writing style is not homogeneous accross our final decisions
# When I'm back from Germany I will work on another solution 

def contains_keywords(text, keywords):
    if text is None:
        return False
    text_lower = text.lower()
    return any(keyword.lower() in text_lower for keyword in keywords)

# First set of keywords
keywords_confirm = ['fundada', 'fundado', 'fundadas', 'fundados', 'a favor']

# Second set of keywords
keywords_reverse = ['infundada', 'improcedente', 'infundado', 'infundadas', 'infundados', 'no procede']

# Apply the function to create the 'Confirm' column
first_instance['confirm'] = first_instance['summary'].apply(contains_keywords, args=(keywords_confirm,))

# Apply the function to create the 'Reverse' column conditionally
first_instance['reverse'] = first_instance.apply(
    lambda row: contains_keywords(row['summary'], keywords_reverse) if not row['confirm'] else False, axis=1
)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2588\263601607.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_instance['confirm'] = first_instance['summary'].apply(contains_keywords, args=(keywords_confirm,))
# C:\Users\PC\AppData\Local\Temp\ipykernel_2588\263601607.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_instance['reverse'] = first_instance.apply(

# %% [markdown]
# ## 3. Getting the gender from names
#
# I'm working with the following csvs that contains male and female names: https://github.com/marcboquet/spanish-names
#
# Here is a need for improvement, the female name detector is not working properly.

# %%
# Reading datasets

parts_2018 = pd.read_csv(r"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\08_CEJ_Web\data_cleaned\DF_procedural_parts_2018.csv")
female_names = pd.read_csv(r"D:\Proyectos\amag\pruebas\mujeres.csv")
female_names = female_names.dropna()
male_names = pd.read_csv(r"D:\Proyectos\amag\pruebas\hombres.csv")
male_names = male_names.dropna()

# %%
parts_2018
# Out:
#                     Expediente N°:       Parte Tipo dePersona  \
# 0       00001-2018-0-0201-JP-CI-02   DEMANDADO        NATURAL
# 1       00001-2018-0-0201-JP-CI-02  DEMANDANTE        NATURAL
# 2       00001-2018-0-0202-JP-CI-01   DEMANDADO        NATURAL
# 3       00001-2018-0-0202-JP-CI-01  DEMANDANTE        NATURAL
# 4       00002-2018-0-0201-JP-CI-01  DEMANDANTE        NATURAL
# ...                            ...         ...            ...
# 365795  00006-2018-0-3301-SP-FC-01  DEMANDANTE        NATURAL
# 365796  00007-2018-0-3301-SP-FC-01   DEMANDADO        NATURAL
# 365797  00007-2018-0-3301-SP-FC-01  DEMANDANTE        NATURAL
# 365798  00001-2018-1-3301-SP-LA-01     QUEJOSO       JURIDICA
# 365799  00001-2018-1-3301-SP-LA-01     QUEJADO       JURIDICA
#
#        Apellido Paterno /Razón Social  \
# 0                              ZAVALA
# 1                              ZAVALA
# 2                             CAMONES
# 3                           FERNANDEZ
# 4                            GRANADOS
# ...                               ...
# 365795                        MORALES
# 365796                           ALVA
# 365797                          PEREZ
# 365798                            NaN
# 365799                            NaN
#
#                                           ApellidoMaterno  \
# 0                                                   CERNA
# 1                                                   CERNA
# 2                                                 MAGUIÑA
# 3                                               FERNANDEZ
# 4                                               RODRIGUEZ
# ...                                                   ...
# 365795                                           OLIVARES
# 365796                                         DEL AGUILA
# 365797                                             CAMPOS
# 365798  \t\t\t\t\t\t\t\t\t\t\t\t\t\tCONSORCIO EDUCATIV...
# 365799  \t\t\t\t\t\t\t\t\t\t\t\t\t\tJUZGADO DE TRABAJO...
#
#                            Nombres
# 0                          NEMESIO
# 1                        CLEMENCIA
# 2                   ORLANDO AMADOR
# 3                    LUCIO ENRIQUE
# 4                        GUILLERMO
# ...                            ...
# 365795             FIORELA LISBETH
# 365796                       ELVIS
# 365797                      LEONOR
# 365798  \t\t\t\t\t\t\t\t\t\t\t\t\t
# 365799  \t\t\t\t\t\t\t\t\t\t\t\t\t
#
# [365800 rows x 6 columns]

# %%
male = male_names['nombre'].tolist()
female = female_names['nombre'].tolist()

# %%
def contains_any_name(text, names):
    if pd.isna(text):  # Check if text is NaN
        return False
    elif any(name in text for name in names):  # Check if any name is in the text
        return True
    else:
        return False

# Apply the function to the 'Nombres' column
parts_2018['female_part'] = parts_2018['Nombres'].apply(lambda x: contains_any_name(x, female))

# %%
parts_2018
# Out:
#                     Expediente N°:       Parte Tipo dePersona  \
# 0       00001-2018-0-0201-JP-CI-02   DEMANDADO        NATURAL
# 1       00001-2018-0-0201-JP-CI-02  DEMANDANTE        NATURAL
# 2       00001-2018-0-0202-JP-CI-01   DEMANDADO        NATURAL
# 3       00001-2018-0-0202-JP-CI-01  DEMANDANTE        NATURAL
# 4       00002-2018-0-0201-JP-CI-01  DEMANDANTE        NATURAL
# ...                            ...         ...            ...
# 365795  00006-2018-0-3301-SP-FC-01  DEMANDANTE        NATURAL
# 365796  00007-2018-0-3301-SP-FC-01   DEMANDADO        NATURAL
# 365797  00007-2018-0-3301-SP-FC-01  DEMANDANTE        NATURAL
# 365798  00001-2018-1-3301-SP-LA-01     QUEJOSO       JURIDICA
# 365799  00001-2018-1-3301-SP-LA-01     QUEJADO       JURIDICA
#
#        Apellido Paterno /Razón Social  \
# 0                              ZAVALA
# 1                              ZAVALA
# 2                             CAMONES
# 3                           FERNANDEZ
# 4                            GRANADOS
# ...                               ...
# 365795                        MORALES
# 365796                           ALVA
# 365797                          PEREZ
# 365798                            NaN
# 365799                            NaN
#
#                                           ApellidoMaterno  \
# 0                                                   CERNA
# 1                                                   CERNA
# 2                                                 MAGUIÑA
# 3                                               FERNANDEZ
# 4                                               RODRIGUEZ
# ...                                                   ...
# 365795                                           OLIVARES
# 365796                                         DEL AGUILA
# 365797                                             CAMPOS
# 365798  \t\t\t\t\t\t\t\t\t\t\t\t\t\tCONSORCIO EDUCATIV...
# 365799  \t\t\t\t\t\t\t\t\t\t\t\t\t\tJUZGADO DE TRABAJO...
#
#                            Nombres  female_part
# 0                          NEMESIO        False
# 1                        CLEMENCIA         True
# 2                   ORLANDO AMADOR         True
# 3                    LUCIO ENRIQUE         True
# 4                        GUILLERMO         True
# ...                            ...          ...
# 365795             FIORELA LISBETH         True
# 365796                       ELVIS        False
# 365797                      LEONOR         True
# 365798  \t\t\t\t\t\t\t\t\t\t\t\t\t        False
# 365799  \t\t\t\t\t\t\t\t\t\t\t\t\t        False
#
# [365800 rows x 7 columns]

# %% [markdown]
# ### 4. Getting the judges with IAT score

# %%
from fuzzywuzzy import fuzz

def check_similarity(value, comparison_list, threshold=90):
    value = str(value)  # Convert value to string
    for comparison_value in comparison_list:
        if fuzz.ratio(value, comparison_value) >= threshold:
            return True
    return False

# Ensure that the columns are of type string
first_instance['judge_from_opinion'] = first_instance['judge_from_opinion'].astype(str)
comparison_list_apellido_nombre = [str(name) for name in amag['participant_apellido_nombre'].tolist()]
comparison_list_nombre_apellido = [str(name) for name in amag['participant_nombre_apellido'].tolist()]

# Check for similarities
similarities = []
for value in first_instance['judge_from_opinion']:
    if (check_similarity(value, comparison_list_apellido_nombre) or 
        check_similarity(value, comparison_list_nombre_apellido)):
        similarities.append(value)

# Filter the DataFrame based on similarities
iat_judges = first_instance[first_instance['judge_from_opinion'].isin(similarities)]
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2588\4076019996.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_instance['judge_from_opinion'] = first_instance['judge_from_opinion'].astype(str)

# %%
iat_judges.to_csv(r"D:\Proyectos\amag\iat_bernardo\iat_judges_2018.csv", index= False)

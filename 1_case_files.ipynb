# %% [markdown]
# # Case File Creation Notebook
#
# This notebook creates a file called `case_file`, which serves as the foundation for extracting information for our projects. It merges and cleans the following datasets, which were generated through our web scraping process:
#
# - **DF_follow_up_cleaner_{year}.csv**
# - **DF_file_report_{year}.csv**
# - **DF_DOWNLOADS_{year}.csv**
#
# The contents and structure of each dataset are explained in detail in a separate file.
#
# The steps involved in this notebook include:
# 1. Loading the datasets.
# 2. Merging the datasets based on legal grounds.
# 3. Cleaning the data.
# 4. Creating the final `case_file` to be used in subsequent analysis.
#
# The result is a clean and consolidated dataset that forms the base for further data processing and project analysis.

# %%
import pandas as pd

# Introduce the year variable you want to work with
year = '2018'

# %%
# Loading the first two datasets

df_follow = pd.read_csv(rf"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\08_CEJ_Web\data_cleaned\DF_follow_up_cleaner_{year}.csv", error_bad_lines=False)
df_follow = df_follow.dropna(subset=['link'])
df_file = pd.read_csv(rf"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\08_CEJ_Web\data_cleaned\DF_file_report_{year}.csv")
df_file = df_file.drop_duplicates(keep ='first')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7304\2846581089.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_follow = pd.read_csv(rf"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\08_CEJ_Web\data_cleaned\DF_follow_up_cleaner_{year}.csv", error_bad_lines=False)
# Skipping line 147793: expected 10 fields, saw 18
#
# Skipping line 403502: expected 10 fields, saw 14
# Skipping line 403503: expected 10 fields, saw 13
# Skipping line 406865: expected 10 fields, saw 19
# Skipping line 411463: expected 10 fields, saw 19
# Skipping line 417503: expected 10 fields, saw 21
# Skipping line 424997: expected 10 fields, saw 16
# Skipping line 426098: expected 10 fields, saw 11
# Skipping line 426296: expected 10 fields, saw 12
# Skipping line 432261: expected 10 fields, saw 13
# Skipping line 433084: expected 10 fields, saw 12
# Skipping line 436799: expected 10 fields, saw 16
#
# Skipping line 556892: expected 10 fields, saw 16
# Skipping line 566502: expected 10 fields, saw 20
#
# Skipping line 827140: expected 10 fields, saw 25
#
# Skipping line 937523: expected 10 fields, saw 21
#
# Skipping line 1050871: expected 10 fields, saw 12
# Skipping line 1093747: expected 10 fields, saw 21
# Skipping line 1093766: expected 10 fields, saw 18
# Skipping line 1096687: expected 10 fields, saw 15
# Skipping line 1112210: expected 10 fields, saw 11
#
# Skipping line 1115300: expected 10 fields, saw 11
# Skipping line 1128023: expected 10 fields, saw 29
# Skipping line 1155564: expected 10 fields, saw 14
# Skipping line 1160605: expected 10 fields, saw 11
# Skipping line 1164815: expected 10 fields, saw 14
# Skipping line 1168982: expected 10 fields, saw 14
#
# Skipping line 1190923: expected 10 fields, saw 14
# Skipping line 1207009: expected 10 fields, saw 13
# Skipping line 1239142: expected 10 fields, saw 12
#
# Skipping line 1266120: expected 10 fields, saw 23
#
# Skipping line 1417167: expected 10 fields, saw 24
#
# Skipping line 1492578: expected 10 fields, saw 19
#
# Skipping line 1596819: expected 10 fields, saw 11
#
# Skipping line 1641454: expected 10 fields, saw 11
# Skipping line 1659219: expected 10 fields, saw 11
# Skipping line 1669454: expected 10 fields, saw 11
# Skipping line 1681275: expected 10 fields, saw 15
# Skipping line 1703396: expected 10 fields, saw 12

# %% [markdown]
# ### Removing Duplicated Case Files and Handling Missing Judge Information
#
# To ensure data consistency and avoid errors in the next steps, we need to clean our dataset by removing certain case files that could introduce problems. Specifically, we will address the following issues:
#
# 1. **Duplicated Case Files**:
#    Case files should be unique identifiers, so having duplicate entries indicates an issue. Therefore, we will remove any rows containing duplicated case files.
#
# 2. **Missing Judge Information**:
#    When duplicate case files exist, we will keep the row that contains the name of the judge, as this row is likely more complete. If the judge's name is missing in all duplicates, we will remove all instances of that case file from the dataset.
#
# ### Cleaning Steps:
# - Identify duplicated case files in the dataset.
# - For each duplicated case file:
#    - Keep the row where the judge's name is present.
#    - Remove any rows where the judge's name is missing.
#
# By removing these problematic rows, we ensure the dataset is clean and ready for the next steps of processing.

# %%
# Step 1: Identify duplicated 'Expediente:' values
duplicated_expedientes = df_file[df_file.duplicated(subset=['Expediente N°:'], keep=False)]
duplicated_expedientes
# Out:
#                     Expediente N°:  \
# 98806   00019-2018-0-0909-JP-CI-01
# 144607  00019-2018-0-0909-JP-CI-01
#
#                                    Órgano Jurisdiccional:  \
# 98806   1° JUZGADO DE PAZ LETRADO - Sede JPL Puente Pi...
# 144607         1º JUZGADO DE PAZ LETRADO DE PUENTE PIEDRA
#
#                 Distrito Judicial:                        Juez:  \
# 98806                   LIMA NORTE                <NO DEFINIDO>
# 144607  PUENTE PIEDRA - VENTANILLA  FLOREANO REYES JESUS GLADYS
#
#               Especialista Legal: Fecha de Inicio:            Proceso:  \
# 98806           CAMPOS DEZA NADIA      04/01/2018   UNICO DE EJECUCION
# 144607  CAMPOS DEZA NADIA ARACELI      04/01/2018   UNICO DE EJECUCION
#
#                                              Observación: Especialidad:  \
# 98806   \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
# 144607  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
#
#                              Materia(s):                Estado:  \
# 98806   OBLIGACION DE DAR SUMA DE DINERO  SENTENCIADO/ RESUELTO
# 144607  OBLIGACION DE DAR SUMA DE DINERO  SENTENCIADO/ RESUELTO
#
#        Etapa Procesal: Fecha Conclusión:       Ubicación: Motivo Conclusión:  \
# 98806          GENERAL                    ARCHIVO MODULAR            -------
# 144607         GENERAL                    ARCHIVO MODULAR            -------
#
#                                            Sumilla:
# 98806   DEMANDA DE OBLIGACIÓN DE DAR SUMA DE DINERO
# 144607  DEMANDA DE OBLIGACIÓN DE DAR SUMA DE DINERO

# %%
# Step 2: Identify rows with '<NO DEFINIDO>' in 'Juez:'
no_definido_juez_rows = df_file[df_file['Juez:'] == '<NO DEFINIDO>']
no_definido_juez_rows
# Out:
#                     Expediente N°:  \
# 1006    00270-2018-1-0201-JP-FC-01
# 1700    00027-2018-0-0201-JR-FC-02
# 8500    00089-2018-0-0405-JM-LA-02
# 8599    00007-2018-0-0501-JP-LA-02
# 8608    00011-2018-0-0501-JP-LA-02
# ...                            ...
# 148239  00669-2018-0-3301-JR-FT-01
# 148241  00670-2018-0-3301-JR-FT-01
# 148243  00671-2018-0-3301-JR-FT-01
# 148247  00673-2018-0-3301-JR-FT-01
# 148250  00674-2018-0-3301-JR-FT-01
#
#                                    Órgano Jurisdiccional:  \
# 1006    JUZGADO DE FAMILIA TRANSITORIO (EX 2°)- SEDE C...
# 1700    JUZGADO DE FAMILIA TRANSITORIO (EX 2°)- SEDE C...
# 8500                2° JUZGADO MIXTO DE CAYLLOMA DE MAJES
# 8599    2° JUZGADO DE PAZ LETRADO - SEDE SAN JUAN BAUT...
# 8608    2° JUZGADO DE PAZ LETRADO - SEDE SAN JUAN BAUT...
# ...                                                   ...
# 148239                         JUZGADO CIVIL - SEDE ANCON
# 148241                         JUZGADO CIVIL - SEDE ANCON
# 148243                         JUZGADO CIVIL - SEDE ANCON
# 148247                         JUZGADO CIVIL - SEDE ANCON
# 148250                         JUZGADO CIVIL - SEDE ANCON
#
#                 Distrito Judicial:          Juez:  \
# 1006                        ANCASH  <NO DEFINIDO>
# 1700                        ANCASH  <NO DEFINIDO>
# 8500                      AREQUIPA  <NO DEFINIDO>
# 8599                      AYACUCHO  <NO DEFINIDO>
# 8608                      AYACUCHO  <NO DEFINIDO>
# ...                            ...            ...
# 148239  PUENTE PIEDRA - VENTANILLA  <NO DEFINIDO>
# 148241  PUENTE PIEDRA - VENTANILLA  <NO DEFINIDO>
# 148243  PUENTE PIEDRA - VENTANILLA  <NO DEFINIDO>
# 148247  PUENTE PIEDRA - VENTANILLA  <NO DEFINIDO>
# 148250  PUENTE PIEDRA - VENTANILLA  <NO DEFINIDO>
#
#                    Especialista Legal: Fecha de Inicio:   Proceso:  \
# 1006    AGUILAR ESPINOZA DAVID ALFREDO      27/11/2018       UNICO
# 1700        RIVERA MEJIA LORENA VANEZA      04/01/2018       UNICO
# 8500      MARQUEZ GALARZA ERWIN ROMMEL      11/10/2018   ABREVIADO
# 8599      LLALLICO NUÑEZ NORMA YOLANDA      05/01/2018   EJECUCION
# 8608      LLALLICO NUÑEZ NORMA YOLANDA      17/01/2018   EJECUCION
# ...                                ...              ...        ...
# 148239          CAJAS PEREZ JUAN DIEGO      06/08/2018       UNICO
# 148241          CAJAS PEREZ JUAN DIEGO      06/08/2018       UNICO
# 148243          CAJAS PEREZ JUAN DIEGO      06/08/2018       UNICO
# 148247          CAJAS PEREZ JUAN DIEGO      06/08/2018       UNICO
# 148250          CAJAS PEREZ JUAN DIEGO      06/08/2018       UNICO
#
#                                              Observación:    Especialidad:  \
# 1006    \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...    FAMILIA CIVIL
# 1700    \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...    FAMILIA CIVIL
# 8500    \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...          LABORAL
# 8599    \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...          LABORAL
# 8608    \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...          LABORAL
# ...                                                   ...              ...
# 148239  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...  FAMILIA TUTELAR
# 148241  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...  FAMILIA TUTELAR
# 148243  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...  FAMILIA TUTELAR
# 148247  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...  FAMILIA TUTELAR
# 148250  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...  FAMILIA TUTELAR
#
#                                               Materia(s):  \
# 1006                                            ALIMENTOS
# 1700                                   VIOLENCIA FAMILIAR
# 8500                                           REPOSICION
# 8599    OBLIGACION DE DAR SUMA DE DINERO INICIADAS POR...
# 8608                     OBLIGACION DE DAR SUMA DE DINERO
# ...                                                   ...
# 148239                                 VIOLENCIA FAMILIAR
# 148241                                 VIOLENCIA FAMILIAR
# 148243                                 VIOLENCIA FAMILIAR
# 148247                                 VIOLENCIA FAMILIAR
# 148250                                 VIOLENCIA FAMILIAR
#
#                       Estado: Etapa Procesal: Fecha Conclusión:  \
# 1006             EN EJECUCION         GENERAL
# 1700        RESUELTO/ATENDIDO         GENERAL
# 8500          EN CALIFICACION         GENERAL
# 8599      ARCHIVO PROVISIONAL         GENERAL
# 8608      ARCHIVO PROVISIONAL         GENERAL
# ...                       ...             ...               ...
# 148239  SENTENCIADO/ RESUELTO         GENERAL
# 148241  SENTENCIADO/ RESUELTO         GENERAL
# 148243  SENTENCIADO/ RESUELTO         GENERAL
# 148247  SENTENCIADO/ RESUELTO         GENERAL
# 148250  SENTENCIADO/ RESUELTO         GENERAL
#
#                   Ubicación: Motivo Conclusión:  \
# 1006            ESPECIALISTA            -------
# 1700    POOL ASIST. JUDICIAL            -------
# 8500         ARCHIVO MODULAR            -------
# 8599         ARCHIVO GENERAL            -------
# 8608         ARCHIVO GENERAL            -------
# ...                      ...                ...
# 148239              FISCALIA            -------
# 148241              FISCALIA            -------
# 148243              FISCALIA            -------
# 148247              FISCALIA            -------
# 148250              FISCALIA            -------
#
#                                            Sumilla:
# 1006       AUXILIO JUDICIAL DE LICEL SÁNCHEZ MIGUEL
# 1700                     DEMANDA VIOLENCIA FAMILIAR
# 8500                                        DEMANDA
# 8599                   SOLICITA REGISTRO DE PODERES
# 8608                   SOLICITA REGISTRO DE PODERES
# ...                                             ...
# 148239  VIOLENCIA FAMILIAR ITINERANCIA EN COMISARIA
# 148241  VIOLENCIA FAMILIAR ITINERANCIA EN COMISARIA
# 148243  VIOLENCIA FAMILIAR ITINERANCIA EN COMISARIA
# 148247  VIOLENCIA FAMILIAR ITINERANCIA EN COMISARIA
# 148250  VIOLENCIA FAMILIAR ITINERANCIA EN COMISARIA
#
# [2108 rows x 16 columns]

# %%
# Step 3: Combine conditions to identify rows to drop
rows_to_drop = duplicated_expedientes[duplicated_expedientes['Juez:'] == '<NO DEFINIDO>'].index
# Step 4: Drop identified rows from the original DataFrame
df_file = df_file.drop(index=rows_to_drop)

# %% [markdown]
# ### Merging Datasets: `df_file` and `df_follow`
#
# In this step, we will merge two key datasets: `df_file` and `df_follow`. The columns included in the merge from `df_file` are carefully selected based on their relevance to our analysis. These columns include information such as case number, jurisdiction, judge, and other relevant metadata.
#
# ### Columns to Include from `df_file`:
# - **Expediente N°:**
# - **Órgano Jurisdiccional:**
# - **Distrito Judicial:**
# - **Juez:**
# - **Fecha de Inicio:**
# - **Proceso:**
# - **Observación:**
# - **Especialidad:**
# - **Materia(s):**

# %%
columns_to_include = ['Expediente N°:', 'Órgano Jurisdiccional:', 'Distrito Judicial:', 'Juez:', 'Fecha de Inicio:',
                      'Proceso:','Observación:','Especialidad:','Materia(s):'] 

# Select only the specified columns from df_follow
df_file = df_file[columns_to_include]

# %%
step_1 = pd.merge(df_follow, df_file, on='Expediente N°:', how='left')
step_1 = step_1.drop_duplicates(keep='first')
step_1
# Out:
#                     Expediente N°:                                      link  \
# 0       00001-2018-0-0201-JP-CI-02  documentoD.html?nid=LRyCGgwXtSvPzXJHvVHJ
# 1       00001-2018-0-0201-JP-CI-02  documentoD.html?nid=QDZWktRZbXuTmWDTKBCO
# 2       00001-2018-0-0201-JP-CI-02   documentoD.html?nid=FwXRolLumnCYTIEsbom
# 3       00001-2018-0-0201-JP-CI-02    documentoD.html?nid=UhGaVIlKXobSwTzhrK
# 4       00001-2018-0-0201-JP-CI-02    documentoD.html?nid=vsMguvWXdydPalfVfm
# ...                            ...                                       ...
# 937541  00001-2018-1-3301-SP-LA-01   documentoD.html?nid=vqyztkCijSEniYVaReF
# 937542  00001-2018-1-3301-SP-LA-01  documentoD.html?nid=plXYcGwKqMvavwzvSpiI
# 937543  00001-2018-1-3301-SP-LA-01     documentoD.html?nid=ksGfhNxGiZvZrYYae
# 937544  00001-2018-1-3301-SP-LA-01   documentoD.html?nid=WSiCFfOXyIaQCLtDTks
# 937545  00001-2018-1-3301-SP-LA-01      documentoD.html?nid=YUkrPXBkNlDrAnBV
#
#        Fecha de Resolución/Ingreso:   Resolución: Tipo de Notificación:  \
# 0                        22/02/2021       CATORCE      Pta. Cedula Not.
# 1                        20/01/2021        OFICIO                   NaN
# 2                        13/11/2020          OCHO      Pta. Cedula Not.
# 3                        10/03/2020  INFORME ORAL                   NaN
# 4                        30/10/2019         NUEVE      Pta. Cedula Not.
# ...                             ...           ...                   ...
# 937541                   17/10/2018          TRES      Pta. Cedula Not.
# 937542                   22/11/2018         CINCO      Pta. Cedula Not.
# 937543                   05/11/2018        CUATRO      Pta. Cedula Not.
# 937544                   03/10/2018           DOS      Pta. Cedula Not.
# 937545                   24/09/2018           UNO      Pta. Cedula Not.
#
#                Acto:  Fojas/Folios:   Proveido:  \
# 0            DECRETO            1.0  22/02/2021
# 1             OFICIO            1.0  20/01/2021
# 2            DECRETO            1.0  13/11/2020
# 3       INFORME ORAL            1.0  10/03/2020
# 4            DECRETO            1.0  07/11/2019
# ...              ...            ...         ...
# 937541          AUTO            8.0  29/10/2018
# 937542          AUTO            1.0  27/11/2018
# 937543          AUTO            1.0  05/11/2018
# 937544          AUTO            1.0  03/10/2018
# 937545          AUTO            2.0  27/09/2018
#
#                                                  Sumilla:  \
# 0       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tTÉNGASE POR ...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tOFICIO DEVOL...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tESTANDO A LA...
# 3       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tINFORME ORAL...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSEÑÁLESE FEC...
# ...                                                   ...
# 937541  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tRESUELVE:   ...
# 937542  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tVISTA LA RAZ...
# 937543  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t1°)\tCORREGI...
# 937544  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAUTOS VISTOS...
# 937545  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t1°)\tDECLARA...
#
#                                   Descripción de Usuario:  \
# 0       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 3       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# ...                                                   ...
# 937541  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 937542  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 937543  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 937544  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
# 937545  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDESCARGADO P...
#
#                        Órgano Jurisdiccional:          Distrito Judicial:  \
# 0       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 1       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 2       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 3       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 4       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# ...                                       ...                         ...
# 937541                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937542                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937543                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937544                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937545                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
#
#                                        Juez: Fecha de Inicio:    Proceso:  \
# 0       SANTISTEBAN VALENZUELA AILLENY ADELA      05/01/2018   SUMARISIMO
# 1       SANTISTEBAN VALENZUELA AILLENY ADELA      05/01/2018   SUMARISIMO
# 2       SANTISTEBAN VALENZUELA AILLENY ADELA      05/01/2018   SUMARISIMO
# 3       SANTISTEBAN VALENZUELA AILLENY ADELA      05/01/2018   SUMARISIMO
# 4       SANTISTEBAN VALENZUELA AILLENY ADELA      05/01/2018   SUMARISIMO
# ...                                      ...              ...         ...
# 937541                 OTÁROLA PAREDES MARÍA      20/09/2018   SUMARISIMO
# 937542                 OTÁROLA PAREDES MARÍA      20/09/2018   SUMARISIMO
# 937543                 OTÁROLA PAREDES MARÍA      20/09/2018   SUMARISIMO
# 937544                 OTÁROLA PAREDES MARÍA      20/09/2018   SUMARISIMO
# 937545                 OTÁROLA PAREDES MARÍA      20/09/2018   SUMARISIMO
#
#                                              Observación: Especialidad:  \
# 0       \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
# 1       \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
# 2       \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
# 3       \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
# 4       \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...         CIVIL
# ...                                                   ...           ...
# 937541  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...       LABORAL
# 937542  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...       LABORAL
# 937543  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...       LABORAL
# 937544  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...       LABORAL
# 937545  \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t...       LABORAL
#
#              Materia(s):
# 0        COBRO DE DINERO
# 1        COBRO DE DINERO
# 2        COBRO DE DINERO
# 3        COBRO DE DINERO
# 4        COBRO DE DINERO
# ...                  ...
# 937541  QUEJA DE DERECHO
# 937542  QUEJA DE DERECHO
# 937543  QUEJA DE DERECHO
# 937544  QUEJA DE DERECHO
# 937545  QUEJA DE DERECHO
#
# [937546 rows x 18 columns]

# %% [markdown]
# ### Loading Text Data and Merging with Metadata
#
# Now that we have the case files along with the associated metadata, the next step is to merge this information with the text data. The text data is stored in the `DF_DOWNLOADS` dataset, which contains the textual content related to each case file. By merging this dataset with the result from `step_1`, we will link the case metadata to its corresponding text.
#
# ### Steps:
#
# 1. **Loading the `DF_DOWNLOADS` Dataset:**
#    We will load the `DF_DOWNLOADS` dataset, which contains the text associated with each case file.
#
# 2. **Merging `DF_DOWNLOADS` with the Result from `step_1`:**
#    We will merge `DF_DOWNLOADS` with the dataset obtained from `step_1`, using the column `link` as the common key. This will allow us to combine the metadata with the corresponding text for each case.

# %%
df_downloads = pd.read_csv(rf"C:\Users\PC\Daniel Chen Dropbox\Alexis Malca\Peru_Justice\02_Data\08_CEJ_Web\data_cleaned\DF_DOWNLOADS_{year}.csv")
df_downloads = df_downloads.drop_duplicates(subset=['link'])

# %%
step_2 = pd.merge(step_1, df_downloads, on='link', how='left')

columns_to_remove = [
    'Tipo de Notificación:',
    'Fojas/Folios:',
    'Descripción de Usuario:',
    'expediente_num',
    'num',
    'error',
    'file_path',
    'Observación:'
]

# Remove the specified columns
step_2 = step_2.drop(columns=columns_to_remove)

# %%
new_columns = {
    'Expediente N°:': 'case_file',
    'link': 'id',
    'Fecha de Resolución/Ingreso:': 'issued_date',
    'Resolución:': 'resolution_number',
    'Acto:': 'resolution_type',
    'Proveido:': 'notified_date',
    'Sumilla:': 'summary',
    'Órgano Jurisdiccional:': 'court',
    'Distrito Judicial:': 'judicial_district',
    'Juez:': 'judge',
    'Especialista Legal:': 'clerk',
    'Fecha de Inicio:': 'start_date',
    'Proceso:': 'procedure_type',
    'Especialidad:': 'law_field',
    'Materia(s):': 'sub_law_field',
    'Estado:': 'status',
    'Etapa Procesal:': 'procedural_stage',
    'text': 'opinion_text'
}

# Rename the columns
step_2 = step_2.rename(columns=new_columns)

# %%
from datetime import datetime

step_2['start_date'] = step_2['start_date'].str.strip()

# Convert 'start_date' column to datetime format
step_2['start_date'] = pd.to_datetime(step_2['start_date'], format='%d/%m/%Y', errors='coerce')

# Convert 'issued_date' column to datetime format
step_2['issued_date'] = pd.to_datetime(step_2['issued_date'], errors='coerce')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7304\1359599876.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   step_2['issued_date'] = pd.to_datetime(step_2['issued_date'], errors='coerce')

# %% [markdown]
# ### Extracting Judge Names to Complement Metadata
#
# In some cases, the metadata may not include the name of the judge, or it may contain incorrect information. To enhance the accuracy of our dataset, we will extract the judge's name directly from the text associated with each case file using regular expressions (regex).

# %%
import regex as re 

# Define patterns
pattern1 = r'J\s*U\s*E\s*Z\s*:\s*'
pattern2 = r'\n'

# Extract text using regex
def extract_judge(row):
    opinion_text = row['opinion_text']
    
    # Ensure the opinion_text is a string
    if not isinstance(opinion_text, str):
        return None
    
    match1 = re.search(pattern1, opinion_text, flags=re.IGNORECASE | re.DOTALL)

    if match1:
        start_index = match1.end()
        # Find the next newline after the start_index
        match2 = re.search(pattern2, opinion_text[start_index:], flags=re.IGNORECASE | re.DOTALL)
        
        if match2:
            end_index = start_index + match2.start()
        else:
            end_index = len(opinion_text)

        return opinion_text[start_index:end_index].strip()
    else:
        return None

# %%
step_2['judge_from_opinion'] = step_2.apply(extract_judge, axis = 1)
# Out:
#                          case_file                                        id  \
# 0       00001-2018-0-0201-JP-CI-02  documentoD.html?nid=LRyCGgwXtSvPzXJHvVHJ
# 1       00001-2018-0-0201-JP-CI-02  documentoD.html?nid=QDZWktRZbXuTmWDTKBCO
# 2       00001-2018-0-0201-JP-CI-02   documentoD.html?nid=FwXRolLumnCYTIEsbom
# 3       00001-2018-0-0201-JP-CI-02    documentoD.html?nid=UhGaVIlKXobSwTzhrK
# 4       00001-2018-0-0201-JP-CI-02    documentoD.html?nid=vsMguvWXdydPalfVfm
# ...                            ...                                       ...
# 937541  00001-2018-1-3301-SP-LA-01   documentoD.html?nid=vqyztkCijSEniYVaReF
# 937542  00001-2018-1-3301-SP-LA-01  documentoD.html?nid=plXYcGwKqMvavwzvSpiI
# 937543  00001-2018-1-3301-SP-LA-01     documentoD.html?nid=ksGfhNxGiZvZrYYae
# 937544  00001-2018-1-3301-SP-LA-01   documentoD.html?nid=WSiCFfOXyIaQCLtDTks
# 937545  00001-2018-1-3301-SP-LA-01      documentoD.html?nid=YUkrPXBkNlDrAnBV
#
#        issued_date resolution_number resolution_type notified_date  \
# 0       2021-02-22           CATORCE         DECRETO    22/02/2021
# 1       2021-01-20            OFICIO          OFICIO    20/01/2021
# 2       2020-11-13              OCHO         DECRETO    13/11/2020
# 3       2020-10-03      INFORME ORAL    INFORME ORAL    10/03/2020
# 4       2019-10-30             NUEVE         DECRETO    07/11/2019
# ...            ...               ...             ...           ...
# 937541  2018-10-17              TRES            AUTO    29/10/2018
# 937542  2018-11-22             CINCO            AUTO    27/11/2018
# 937543  2018-05-11            CUATRO            AUTO    05/11/2018
# 937544  2018-03-10               DOS            AUTO    03/10/2018
# 937545  2018-09-24               UNO            AUTO    27/09/2018
#
#                                                   summary  \
# 0       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tTÉNGASE POR ...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tOFICIO DEVOL...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tESTANDO A LA...
# 3       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tINFORME ORAL...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSEÑÁLESE FEC...
# ...                                                   ...
# 937541  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tRESUELVE:   ...
# 937542  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tVISTA LA RAZ...
# 937543  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t1°)\tCORREGI...
# 937544  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAUTOS VISTOS...
# 937545  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t1°)\tDECLARA...
#
#                                         court           judicial_district  \
# 0       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 1       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 2       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 3       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# 4       2° JUZGADO PAZ LETRADO - Sede Central                      ANCASH
# ...                                       ...                         ...
# 937541                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937542                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937543                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937544                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
# 937545                     JUZGADO DE TRABAJO  PUENTE PIEDRA - VENTANILLA
#
#                                        judge start_date procedure_type  \
# 0       SANTISTEBAN VALENZUELA AILLENY ADELA 2018-01-05     SUMARISIMO
# 1       SANTISTEBAN VALENZUELA AILLENY ADELA 2018-01-05     SUMARISIMO
# 2       SANTISTEBAN VALENZUELA AILLENY ADELA 2018-01-05     SUMARISIMO
# 3       SANTISTEBAN VALENZUELA AILLENY ADELA 2018-01-05     SUMARISIMO
# 4       SANTISTEBAN VALENZUELA AILLENY ADELA 2018-01-05     SUMARISIMO
# ...                                      ...        ...            ...
# 937541                 OTÁROLA PAREDES MARÍA 2018-09-20     SUMARISIMO
# 937542                 OTÁROLA PAREDES MARÍA 2018-09-20     SUMARISIMO
# 937543                 OTÁROLA PAREDES MARÍA 2018-09-20     SUMARISIMO
# 937544                 OTÁROLA PAREDES MARÍA 2018-09-20     SUMARISIMO
# 937545                 OTÁROLA PAREDES MARÍA 2018-09-20     SUMARISIMO
#
#        law_field     sub_law_field  \
# 0          CIVIL   COBRO DE DINERO
# 1          CIVIL   COBRO DE DINERO
# 2          CIVIL   COBRO DE DINERO
# 3          CIVIL   COBRO DE DINERO
# 4          CIVIL   COBRO DE DINERO
# ...          ...               ...
# 937541   LABORAL  QUEJA DE DERECHO
# 937542   LABORAL  QUEJA DE DERECHO
# 937543   LABORAL  QUEJA DE DERECHO
# 937544   LABORAL  QUEJA DE DERECHO
# 937545   LABORAL  QUEJA DE DERECHO
#
#                                              opinion_text  \
# 0        \n\n:  \n:  \n:  \n:  \n:  \n:  \n\n2° JUZGAD...
# 1        \n\n \n \n\n \n\nCORTE SUPERIOR DE JUSTICIA D...
# 2       1°JUZGADO CIVIL SEDE HUARAZ \n\nEXPEDIENTE \n\...
# 3       \n                    Corte Superior de Justic...
# 4        \n\n1°JUZGADO CIVIL SEDE HUARAZ \nEXPEDIENTE ...
# ...                                                   ...
# 937541   \n\n \n\nIlustre Corte Superior de  \n\nJusti...
# 937542  : 00001-2018-1-3301-SP-LA-01 \n: QUEJA DE DERE...
# 937543   \n\nCORTE SUPERIOR DE JUSTICIA DE VENTANILLA ...
# 937544   \n\nCORTE SUPERIOR DE JUSTICIA DE VENTANILLA ...
# 937545   \n\nCORTE SUPERIOR DE JUSTICIA DE VENTANILLA ...
#
#               judge_from_opinion
# 0                           None
# 1                           None
# 2       MANRIQUE GAMARRA, KARINA
# 3       MANRIQUE GAMARRA, KARINA
# 4       MANRIQUE GAMARRA, KARINA
# ...                          ...
# 937541                      None
# 937542                      None
# 937543                      None
# 937544                      None
# 937545                      None
#
# [937546 rows x 16 columns]

# %% [markdown]
# ### Creating the `verdict_text` Column
#
# To enhance our dataset with critical information regarding the outcome of each case, we will create a new column called `verdict_text`. This column will capture the judge's final decision. This information is vital for understanding the outcomes of the cases and assessing judicial decisions.
#
# ### Definition of Verdict Text
#
# The `verdict_text` is defined as the last 300 words that appear in the *opinion text* of each case. By extracting this portion of the text, we can directly analyze the judge's concluding remarks and decisions.
#
# ### Steps to Create the `verdict_text` Column:
#
# 1. **Extracting the Last 300 Words:**
#    We will retrieve the last 300 words from the opinion text for each case. This will provide us with the final section where the judge outlines the verdict and reasoning.
#
# 2. **Populating the `verdict_text` Column:**
#    After extracting the relevant text, the `verdict_text` column will be populated with these last 300 words for each case. This will allow for a clearer understanding of the verdict delivered by the judge.
#
# ### Resulting Dataset
#
# The addition of the `verdict_text` column will provide a clearer understanding of each case's outcome. This will facilitate further analysis of judicial decisions and help identify patterns in how different judges handle claims.

# %%
def extract_last_n_words(text, n=300):
    if isinstance(text, str):
        words = text.split()
        last_n_words = words[-n:]
        return ' '.join(last_n_words)
    else:
        return ''  
step_2['verdict_text'] = step_2['opinion_text'].apply(lambda x: extract_last_n_words(x))

# %% [markdown]
# ### Important Considerations for the Dataset
#
# When working with the *Consulta de Expediente Judicial*, it's essential to understand the context and nuances of the data being analyzed. This dataset includes all texts produced throughout the legal procedure, capturing various judicial opinions and documents. Here are some key points to consider:
#
# 1. **Judge Identification**:
#    The column `judge_from_opinion` may contain the name of a different judge, especially in cases where the procedure involves an *appellation* or other types of *recurso de revisión* (review remedies). In these scenarios, the case is typically reviewed by another judge, which means the name recorded in `judge_from_opinion` will differ from the judge originally assigned to the case.
#
# 2. **Impact on Performance Assessment**:
#    When assessing the performance of each judge based on this dataset, it is crucial to account for this discrepancy. The presence of multiple judges handling the same case can lead to skewed interpretations of performance metrics, such as:
#    - Case resolution time
#    - Ruling consistency
#    - Outcome analysis
#
# 3. **Data Interpretation**:
#    Analysts must be mindful of the context in which the judge's name appears. For instance:
#    - If the `judge_from_opinion` reflects the reviewing judge, this may not accurately represent the initial judge's handling of the case.
#    - A comprehensive analysis should consider the roles of both judges (the initial and the reviewing judge) to present a fair evaluation of judicial performance.
#
# ### Recommendations:
# - When analyzing performance metrics, differentiate between the initial judge and any reviewing judges involved in the case.
# - Consider creating separate metrics or analyses that account for the nuances introduced by the *recurso de revisión* processes.
#
# By keeping these considerations in mind, we can ensure a more accurate and nuanced understanding of judicial performance as derived from the dataset.

# %%
step_2.to_csv(rf"D:\Proyectos\amag\case_files_{year}.csv", index=False)
